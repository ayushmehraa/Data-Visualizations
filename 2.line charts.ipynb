# %% [markdown]
# # Setup environment

# %% [markdown]
# ### Import modules required select and load the dataset (spotify.csv) we reqiure for our notebook.

# %%
# modules for our notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# file-path of our dataset
file_path = r'D:\jypyter notebooks\kaggle\visualizations\dataset\spotify.csv'

# load dataset in df variable
df = pd.read_csv(file_path,index_col='Date',parse_dates=True)

# %% [markdown]
# # Examine the data
# check what our data contain

# %%
# checking first 5 rows of our dataset
df.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %% [markdown]
# Empty entries will appear as NaN, which is short for "Not a Number".

# %% [markdown]
# We can also take a look at the last five rows of the data by making only one small change (where .head() becomes .tail())

# %%
# last 5 rows of dataset
df.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %% [markdown]
# # Plot the data

# %% [markdown]
# Now that the dataset is loaded into the notebook, we need only one line of code to make a line chart!

# %%
# line chart showing global streams of a song
sns.lineplot(data=df)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Sometimes there are additional details we'd like to modify, like the size of the figure and the title of the chart. Each of these options can easily be set with a single line of code.

# %%
# set figure size
plt.figure(figsize=(14,6))

# set title of figure
plt.title('Daily stream of popular songs in 2017-2018')

sns.lineplot(data=df)
# Out:
# <AxesSubplot:title={'center':'Daily stream of popular songs in 2017-2018'}, xlabel='Date'>

# %% [markdown]
# # Plot a subset of the data
# we've learned how to plot a line for every column in the dataset. In this section, we'll learn how to plot a subset of the columns.

# %% [markdown]
# We'll begin by printing the names of all columns. This is done with one line of code and can be adapted for any dataset by just swapping out the name of the dataset (in this case, spotify_data).

# %%
list(df.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %% [markdown]
# In the next code cell, we plot the lines corresponding to the first two columns in the dataset.

# %%
# set size of plot
plt.figure(figsize=(14,6))

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=df['Shape of You'], label='Shape of You')

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=df['Despacito'], label='Despacito')

plt.title('Daily stream of popular songs in 2017-2018')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')
