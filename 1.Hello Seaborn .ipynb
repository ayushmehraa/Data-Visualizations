# %% [markdown]
# # Hello seaborn

# %% [markdown]
# # setup notebook

# %%
# In every notebook first we need to setup our coding environment at top, like importing moudles and data set
# we needed for our notebook

# useful modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('steup complete!')
# Out:
# steup complete!

# %% [markdown]
# # load dataset

# %% [markdown]
# In this notebook, we'll work with a dataset of historical FIFA rankings for six countries: Argentina (ARG), Brazil (BRA), Spain (ESP), France (FRA), Germany (GER), and Italy (ITA). The dataset is stored as a CSV file (short for comma-separated values file. Opening the CSV file in Excel shows a row for each date, along with a column for each country.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# To load the data into the notebook, we'll use two distinct steps, implemented in the code cell below as follows:
# <br>
#
# <ul>begin by specifying the location (or filepath) where the dataset can be accessed, and then</ul>
# <ul>use the filepath to load the contents of the dataset into the notebook.</ul>

# %%
# file-path
file_path=r'D:\jypyter notebooks\kaggle\visualizations\dataset\fifa.csv'

# read the file into variable df (dataframe)
df = pd.read_csv(file_path, index_col = "Date", parse_dates=True)
#                filepath   colum to use as    recoginize row  
#                             row label          labels as dates

# %% [markdown]
# # Examine the data

# %% [markdown]
# Now we look at our dataframe df to make sure it is loaded correctly and also to see what our dataset contains

# %%
df.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# # plot the data

# %% [markdown]
# we'll learn about many different plot types. In many cases, we'll only need one line of code to make a chart.

# %%
# set the width and height of figure
plt.figure(figsize=(16,6))

# line chart showing fifa world cup over time
sns.lineplot(data=df)
# Out:
# <AxesSubplot:xlabel='Date'>
